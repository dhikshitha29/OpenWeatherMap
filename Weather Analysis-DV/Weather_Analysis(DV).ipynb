# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objs as go

# %%
pip install dash==0.21.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-renderer==0.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-html-components==0.7.0
# Out:
# ...
#
# ...

# %%
pip install dash-core-components==0.12.6

# %%
df_w=pd.read_csv("weather1.csv")

# %%
df_w.head()
# Out:
#    Data_Precipitation Date_Full  Date_Month  Date_Week of  Date_Year  \
# 0                0.00  1/3/2020           1             3       2020
# 1                0.00  1/3/2020           1             3       2020
# 2                0.16  1/3/2020           1             3       2020
# 3                0.00  1/3/2020           1             3       2020
# 4                0.01  1/3/2020           1             3       2020
#
#   Station_City Station_Code Station_Location Station_State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data_Temperature_Avg_Temp  Data_Temperature_Max_Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
df_w.isnull().sum()
# Out:
# Data_Precipitation           0
# Date_Full                    0
# Date_Month                   0
# Date_Week of                 0
# Date_Year                    0
# Station_City                 0
# Station_Code                 0
# Station_Location             0
# Station_State                0
# Data_Temperature_Avg_Temp    0
# Data_Temperature_Max_Temp    0
# Data_Temperature_Min_Temp    0
# Data_Wind_Direction          0
# Data_Wind_Speed              0
# dtype: int64

# %%
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data_Precipitation         16743 non-null  float64
#  1   Date_Full                  16743 non-null  object
#  2   Date_Month                 16743 non-null  int64
#  3   Date_Week of               16743 non-null  int64
#  4   Date_Year                  16743 non-null  int64
#  5   Station_City               16743 non-null  object
#  6   Station_Code               16743 non-null  object
#  7   Station_Location           16743 non-null  object
#  8   Station_State              16743 non-null  object
#  9   Data_Temperature_Avg_Temp  16743 non-null  int64
#  10  Data_Temperature_Max_Temp  16743 non-null  int64
#  11  Data_Temperature_Min_Temp  16743 non-null  int64
#  12  Data_Wind_Direction        16743 non-null  int64
# ...

# %%
df_w.describe()
# Out:
#        Data_Precipitation    Date_Month  Date_Week of     Date_Year  \
# count        16743.000000  16743.000000  16743.000000  16743.000000
# mean             0.579090      6.343128     15.650242   2020.018933
# std              0.988057      3.490723      8.923425      0.136294
# min              0.000000      1.000000      1.000000   2020.000000
# 25%              0.000000      3.000000      8.000000   2020.000000
# 50%              0.190000      6.000000     16.000000   2020.000000
# 75%              0.750000      9.000000     24.000000   2020.000000
# max             20.890000     12.000000     31.000000   2021.000000
#
#        Data_Temperature_Avg_Temp  Data_Temperature_Max_Temp  \
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# ...

# %%
countries=df_w["Station_State"].unique()

# %%
countries
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'DE', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'VA', 'Vermont', 'Virginia', 'Washington', 'West Virginia',
#        'Wisconsin', 'Wyoming'], dtype=object)

# %%
fig = px.pie(df_w, values='Date_Year', names='Data_Temperature_Avg_Temp')
fig.show()

# %%
df_c=df_w[df_w["Station_State"]=="Alabama"]
fig = px.bar(df_c, x='Date_Full', y='Data_Temperature_Avg_Temp')
fig.show()

# %%
fig = px.scatter(df_c, x="Data_Wind_Speed", y="Data_Temperature_Avg_Temp",color='Data_Wind_Direction',trendline='ols')
fig.show()        #ONE COUNTRTY

# %%
df = pd.read_csv('Max_temp.csv')

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
df['APR'].plot()
# Out:
# <AxesSubplot:>

# %%
df['APR'].rolling(20).mean().plot()
# Out:
# <AxesSubplot:>

# %%
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
       'NOV', 'DEC']].rolling(20).mean().plot()
# Out:
# <AxesSubplot:>

# %%
df['JAN']
# Out:
# 0      22.40
# 1      24.93
# 2      23.44
# 3      22.50
# 4      22.00
#        ...
# 112    24.56
# 113    23.83
# 114    24.58
# 115    26.94
# 116    26.45
# Name: JAN, Length: 117, dtype: float64

# %%
df.to_csv('Max_temp.csv')

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.shape
# Out:
# (117, 18)

# %%
df = pd.read_csv('Min_temp.csv')

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  13.58  14.72  17.91  20.93  23.18  24.05  23.82  23.58  22.09  20.20
# 1  1902  13.08  14.20  18.44  21.30  23.63  23.97  23.68  23.34  22.11  19.63
# 2  1903  13.20  14.55  17.12  20.67  22.95  23.85  23.53  23.29  22.84  20.12
# 3  1904  13.04  14.07  17.70  21.42  23.02  23.64  23.35  23.03  21.65  19.50
# 4  1905  12.83  12.74  16.88  19.62  23.32  24.13  23.93  24.31  22.47  21.65
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  16.16  13.41   19.51    14.16    20.67    23.38    16.59
# 1  16.35  13.53   19.44    13.64    21.12    23.28    16.50
# 2  15.84  12.93   19.25    13.87    20.25    23.40    16.29
# 3  15.77  14.06   19.22    13.72    20.72    22.96    16.44
# 4  16.63  13.59   19.03    12.81    19.97    23.43    16.39

# %%
df.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
df = df.set_index('YEAR')

# %%
df['JUL'].plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df['JUL'].rolling(10,min_periods=5).mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
       'NOV', 'DEC']].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
       'NOV', 'DEC']].rolling(10).mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
       'NOV', 'DEC']].rolling(20).mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df['JUN'].head(10)
# Out:
# YEAR
# 1901    24.05
# 1902    23.97
# 1903    23.85
# 1904    23.64
# 1905    24.13
# 1906    23.85
# 1907    23.40
# 1908    23.87
# 1909    23.62
# 1910    23.61
# Name: JUN, dtype: float64

# %%
df.to_csv('Min_temp.csv')

# %%
df
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901  13.58  14.72  17.91  20.93  23.18  24.05  23.82  23.58  22.09  20.20
# 1902  13.08  14.20  18.44  21.30  23.63  23.97  23.68  23.34  22.11  19.63
# 1903  13.20  14.55  17.12  20.67  22.95  23.85  23.53  23.29  22.84  20.12
# 1904  13.04  14.07  17.70  21.42  23.02  23.64  23.35  23.03  21.65  19.50
# 1905  12.83  12.74  16.88  19.62  23.32  24.13  23.93  24.31  22.47  21.65
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2013  13.22  15.54  18.45  21.29  23.68  24.08  23.94  23.70  22.70  21.69
# 2014  13.79  14.72  17.73  21.07  23.16  24.68  24.37  23.58  22.57  20.51
# 2015  13.51  15.55  17.99  21.18  23.54  23.82  24.28  23.82  22.52  20.68
# 2016  14.91  17.44  20.59  23.75  25.10  25.36  24.72  24.56  23.78  21.65
# 2017  14.72  16.71  19.55  23.40  25.09  25.07  24.74  24.52  24.01  22.19
#
# ...

# %%
df.shape
# Out:
# (117, 17)

# %%
df = pd.read_csv('Mean_Temp.csv')

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  21.73  18.95   24.23    18.71    26.06    27.30    21.92
# 1  21.33  18.78   24.33    19.70    26.44    27.18    21.49
# 2  20.96  18.29   23.80    19.05    25.47    27.17    21.27
# 3  21.07  18.84   23.86    18.66    25.84    26.83    21.42
# 4  22.07  18.71   23.71    17.58    24.99    27.37    21.48

# %%
df.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22  26.87
# 113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61
# 114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04
# 115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72
# 116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  25.63  22.18  19.69   24.82    19.98    26.85    27.46    22.50
# 113  25.38  22.53  19.50   24.73    19.58    26.24    27.88    22.47
# 114  25.82  22.95  20.21   24.91    20.12    26.29    27.73    22.99
# 115  26.81  23.90  21.89   26.45    22.25    28.86    28.44    24.20
# 116  27.24  23.92  21.47   26.29    21.84    28.41    28.50    24.21

# %%
df = df.set_index('YEAR')

# %%
df.columns
# Out:
# Index(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP', 'OCT-DEC'],
#       dtype='object')

# %%
df.ANNUAL.values
# Out:
# array([24.23, 24.33, 23.8 , 23.86, 23.71, 24.12, 23.87, 23.95, 23.78,
#        23.77, 23.96, 24.11, 23.88, 24.03, 24.29, 24.08, 23.56, 23.83,
#        24.01, 23.91, 24.33, 24.05, 24.05, 24.15, 23.95, 24.04, 23.94,
#        24.29, 24.08, 23.93, 24.44, 24.21, 23.92, 24.13, 23.98, 24.12,
#        23.98, 23.98, 24.01, 24.06, 24.65, 24.22, 23.93, 24.03, 23.92,
#        24.42, 24.04, 24.11, 24.08, 23.71, 24.22, 24.34, 24.57, 24.13,
#        23.97, 23.96, 23.97, 24.62, 24.3 , 24.29, 24.  , 24.04, 24.15,
#        24.1 , 24.07, 24.36, 24.11, 23.94, 24.46, 24.26, 23.91, 24.1 ,
#        24.41, 24.  , 23.74, 24.07, 24.35, 24.24, 24.57, 24.55, 24.27,
#        24.15, 24.12, 24.26, 24.45, 24.2 , 24.57, 24.42, 24.03, 24.21,
#        24.28, 24.15, 24.43, 24.46, 25.29, 24.55, 24.1 , 24.76, 24.67,
#        24.6 , 24.73, 25.  , 24.72, 24.74, 24.58, 25.06, 24.77, 24.61,
#        25.11, 25.13, 24.67, 24.69, 24.82, 24.73, 24.91, 26.45, 26.29])

# %%
ax1 = df.ANNUAL.plot()

# %%
ax1 = df.ANNUAL.plot()
df.ANNUAL.rolling(20, min_periods=5).mean().plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
df.columns
# Out:
# Index(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP', 'OCT-DEC'],
#       dtype='object')

# %%
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
       'NOV', 'DEC']].rolling(15).mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>
